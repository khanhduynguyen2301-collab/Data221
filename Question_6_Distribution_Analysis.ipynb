# %%
def distribution_analysis(numbers):
    distribution_dictionary = {}
    for number in sorted(set(numbers)):
        counting_matches = sum(1 for element in numbers if element <= number)
        distribution_dictionary[number] = f"{(counting_matches / len(numbers)) * 100:.2f}%"
    return distribution_dictionary

numbers = [3, 1, 2, 3, 4, 2]
print(distribution_analysis(numbers))
# Out:
# {1: '16.67%', 2: '50.00%', 3: '83.33%', 4: '100.00%'}
