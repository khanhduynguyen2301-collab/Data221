# %%
from random import random

values = [random() for i in range(20)]
x = random()

values.sort()

matching_indices = [index for index, value in enumerate(values) if value >= x]

print("Sorted values:", values)
print()
print("x:", x)
print()

if matching_indices:
    print("First matching index:", matching_indices[0])
else:
    print("No matching index found (all values < x).")
# Out:
# Sorted values: [0.061631025182725785, 0.06854674296592489, 0.08742767898329928, 0.2186969059226015, 0.2407627486525734, 0.2601777792576412, 0.28208196414457876, 0.29063852024565473, 0.33146939235550843, 0.3786420249112673, 0.47478827393877077, 0.5941692962354351, 0.6049107058045128, 0.6258639122867323, 0.6540787289088295, 0.6678635641212652, 0.6972293768766892, 0.770538088919949, 0.9321161360924141, 0.9500523283170302]
#
# x: 0.11934682456463896
#
# First matching index: 3
