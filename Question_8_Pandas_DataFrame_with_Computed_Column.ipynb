# %%
import pandas as pd

data = {"A": [1, 2, 2, 1],
        "B": [3.1, 4.2, 1.5, 6.3],
        "C": [800, 150, 400, 210]
        }

table = pd.DataFrame(data)
table["D"] = [3.1, 4.2, 1.5, 6.3]

print(table)
# Out:
#    A    B    C    D
# 0  1  3.1  800  3.1
# 1  2  4.2  150  4.2
# 2  2  1.5  400  1.5
# 3  1  6.3  210  6.3
