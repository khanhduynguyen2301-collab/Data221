# %%
def nested_dictionary(string):
    result_dictionary = {}
    for word in string.split():
        result_dictionary[word] = {'length': len(word),
                            'parity': 'even' if len(word) % 2 == 0 else 'odd'}
    return result_dictionary

string = 'data science'
print(nested_dictionary(string))
# Out:
# {'data': {'length': 4, 'parity': 'even'}, 'science': {'length': 7, 'parity': 'odd'}}
